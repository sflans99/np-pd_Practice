# %%
import pandas as pd
import numpy as np
import yfinance as yf
import os
from dotenv import load_dotenv

# %%
import os

# Define the current name of the file
old_name = "help.txt"

# Define the new, correct name
new_name = ".env"

try:
    # Use the os.rename function to change the file name
    os.rename(old_name, new_name)
    print(f"File successfully renamed from {old_name} to {new_name}")
except FileNotFoundError:
    print(f"Error: The file '{old_name}' was not found.")
except Exception as e:
    print(f"An error occurred during rename: {e}")

# IMPORTANT: Now use load_dotenv() in the next cell to load the variables
# from dotenv import load_dotenv
# load_dotenv()
# Out:
# Error: The file 'help.txt' was not found.

# %%
# Load environment variables from a .env file (if it exists)
load_dotenv()

# Access the API key from the environment
API_KEY = os.getenv("QUIVER_API_KEY")

if API_KEY is None:
    raise ValueError("QUIVER_API_KEY not found. Please set it in your .env file or environment.")

# Now you can use API_KEY in your requests
# requests.get(f"https://api.quiverquant.com/api/v6/endpoint?token={API_KEY}")
conn = http.client.HTTPSConnection("api.quiverquant.com")

headers = {
    'Accept': "application/json",
    'Authorization': [key]
}

conn.request("GET", "/beta/bulk/congresstrading", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 8
#       5 API_KEY = os.getenv("QUIVER_API_KEY")
#       7 if API_KEY is None:
# ----> 8     raise ValueError("QUIVER_API_KEY not found. Please set it in your .env file or environment.")
#      10 # Now you can use API_KEY in your requests
#      11 # requests.get(f"https://api.quiverquant.com/api/v6/endpoint?token={API_KEY}")
#      12 conn = http.client.HTTPSConnection("api.quiverquant.com")
#
# ValueError: QUIVER_API_KEY not found. Please set it in your .env file or environment.
